# %%
import matplotlib.pyplot as plt

# %%
# Question:why beginners use .pyplot
# because it 
# requires less Code 
# is simple and fast 
# automatically creates figures and axes 
# is perfect for learning, exams, and quick analysis

# %%
# from matplotlib.legend import Legend
